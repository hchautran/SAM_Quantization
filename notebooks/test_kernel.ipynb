# %%
from spas_sage_attn import spas_sage2_attn_meansim_topk_cuda
import torch
# Out:
# Warning: Sage2++ NOT enabled

# %%
# !nvidia-smi
# Out:
# Tue Nov  4 10:38:20 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla V100-SXM2-16GB           Off |   00000000:1A:00.0 Off |                    0 |
# | N/A   36C    P0             42W /  300W |      91MiB /  16384MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla V100-SXM2-16GB           Off |   00000000:1C:00.0 Off |                    0 |
# | N/A   33C    P0             41W /  300W |      75MiB /  16384MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   2  Tesla V100-SXM2-16GB           Off |   00000000:1D:00.0 Off |                    0 |
# | N/A   36C    P0             42W /  300W |     103MiB /  16384MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   3  Tesla V100-SXM2-16GB           Off |   00000000:1E:00.0 Off |                    0 |
# | N/A   46C    P0             76W /  300W |   16141MiB /  16384MiB |    100%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# +-----------------------------------------------------------------------------------------+

# %%
q = torch.randn(25, 1, 196, 1024).cuda()
k = torch.randn(25, 1, 196, 1024).cuda()
v = torch.randn(25, 1, 196, 1024).cuda()
attn_output = spas_sage2_attn_meansim_topk_cuda(q, k, v, simthreshd1=-0.1, topk=0.35, pvthreshd=15, is_causal=False)
